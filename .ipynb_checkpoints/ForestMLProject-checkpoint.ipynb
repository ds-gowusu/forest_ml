# %%
import psycopg2 as pg
from sqlalchemy import create_engine

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Database connection parameters
DB_USER = 'postgres'
DB_PASSWORD = 'gogilbert9812806'
DB_NAME = 'psp_db'
DB_HOST = 'localhost'
DB_PORT = '5432'

# Connection string
conn_str = f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

# Connect to Database
engine = create_engine(conn_str)

# %%
# Querying the Database to retrieve relevant data
query = """
    SELECT
        b.plantation,
        p.block,
        b."year planted",
        b."block area (ha)",
        p.plot,
        pmh."Default plot size",
        pmh."Plot type",
        d.area_type,
        d."monitoring year",
        d.tree_id,
        d."Tree SPECIES",
        d.height_m,
        d.dbh_cm,
        d.remarks
    FROM block_register b
    JOIN plot_block_relation p
        ON b.plantation = p.plantation
        AND b.block = p.block
    JOIN plot_monitoring_history pmh
        ON pmh.plantation = p.plantation
        AND pmh.plot = p.plot
    JOIN treedata d
        ON b.plantation = d.plantation
        AND d.plot = p.plot
        AND d.area_type = 'Teak';
"""

# Convert the retrieved data from the database to pandas dataframe
df = pd.read_sql_query(query, engine)


# View the first 5 rows to the dataset
df.head()
# Out:
#   plantation block  year planted  block area (ha) plot  Default plot size  \
# 0    Tain II   B39          2013        63.327094    1              729.0
# 1    Tain II   B39          2013        63.327094    1              729.0
# 2    Tain II   B39          2013        63.327094    1              729.0
# 3    Tain II   B39          2013        63.327094    1              729.0
# 4    Tain II   B39          2013        63.327094    1              729.0
#
#   Plot type area_type  monitoring year  tree_id Tree SPECIES  height_m  \
# 0    Square      Teak           2018.0     71.0         Teak      7.25
# 1    Square      Teak           2018.0     71.0         Teak      7.25
# 2    Square      Teak           2018.0     71.0         Teak      7.25
# 3    Square      Teak           2018.0     71.0         Teak      7.25
# 4    Square      Teak           2018.0     71.0         Teak      7.25
#
#    dbh_cm     remarks
# 0    12.0  Fire scars
# 1    12.0  Fire scars
# 2    12.0  Fire scars
# ...

# %%
# Information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8577780 entries, 0 to 8577779
# Data columns (total 14 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   plantation         object
#  1   block              object
#  2   year planted       int64
#  3   block area (ha)    float64
#  4   plot               object
#  5   Default plot size  float64
#  6   Plot type          object
#  7   area_type          object
#  8   monitoring year    float64
#  9   tree_id            float64
#  10  Tree SPECIES       object
#  11  height_m           float64
#  12  dbh_cm             float64
#  13  remarks            object
# dtypes: float64(6), int64(1), object(7)
# memory usage: 916.2+ MB

# %%
# The shape of the dataset
df.shape
# Out:
# (8577780, 14)

# %%
# Check for null values in the dataset
df.isna().sum()
# Out:
# plantation                 0
# block                      0
# year planted               0
# block area (ha)            0
# plot                       0
# Default plot size          0
# Plot type                  0
# area_type                  0
# monitoring year            0
# tree_id                   72
# Tree SPECIES            1544
# height_m                4788
# dbh_cm                 11404
# remarks              5785624
# dtype: int64

# %%
# Remove the null values in height and diameter
df.dropna(subset=['height_m', 'dbh_cm'], inplace=True)

# %%
# Verify if all null values in the height and diameter are removed
df.isna().sum()
# Out:
# plantation                 0
# block                      0
# year planted               0
# block area (ha)            0
# plot                       0
# Default plot size          0
# Plot type                  0
# area_type                  0
# monitoring year            0
# tree_id                    0
# Tree SPECIES            1468
# height_m                   0
# dbh_cm                     0
# remarks              5778388
# dtype: int64

# %%
# Review this remarks to check if there are values that need to be removed
df['remarks'].unique()
# Out:
# array(['Fire scars', None, 'Beetle infestation', 'Top broken', 'Coppice',
#        'Broken top', 'Forked', 'Dead tree', 'Forked at 30 cm',
#        'Fork at 2m', 'Nearly dead', '2 stems', 'Beside a termite mould',
#        'leaves eaten by grasshoppers', 'Wildling',
#        'Outside planting line - Wildling', 'marked',
#        'bark damaged by termites', 'Dead tree - marked',
#        'Has leaves to about 6m', 'dead tree, but resprouting',
#        'Sapling - Wildling', 'Black ant attack from base to top',
#        'dead tree, but coppicing', 'Old teak stand', 'Double stem',
#        '3 stems', 'The tree is highly branched at this height sideways',
#        'Dying', 'ceber', 'Main tree dead', 'Top dead', '', 'Beaten-up',
#        'Taken with metre tape', 'DBH taken with metre tape',
#        'Forked at DBH, taken above', 'No leaves, but alive',
#        'Taken with metre tape.', 'Diseased', 'top slashed',
#        'Teak dieback', 'Dbh taken with metre tape', 'Top dead - Wildling',
# ...

# %%
# List of all unwanted remarks
unwanted = r"(Wildling|Coppice|Broken top|diseased|Top broken|coppice|wildling|fork|Beetle|Old|dieback|die back|Dying|Diseased|Broken|Abnormal|crooked|marked|dead|Dead,Top broken|Top broken,Half dead|dead,marked|Marked|Abnomal tree)"

# Remove the unwanted values
mask = df['remarks'].str.contains(unwanted, case=False, na=False)
df = df[~mask]
# Out:
# C:\Users\GILBERT FG\AppData\Local\Temp\ipykernel_13280\1576740686.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = df['remarks'].str.contains(unwanted, case=False, na=False)

# %%
# Verify if the unwanted are removed
df['remarks'].unique()
# Out:
# array(['Fire scars', None, '2 stems', 'Beside a termite mould',
#        'leaves eaten by grasshoppers', 'bark damaged by termites',
#        'Has leaves to about 6m', 'Black ant attack from base to top',
#        'Double stem', '3 stems',
#        'The tree is highly branched at this height sideways', 'ceber', '',
#        'Beaten-up', 'Taken with metre tape', 'DBH taken with metre tape',
#        'No leaves, but alive', 'Taken with metre tape.', 'top slashed',
#        'Dbh taken with metre tape', 'Circumference',
#        'Beaten-up. Top slashed', 'Sunto', 'sunto', '2012 teak',
#        '2012 teak, top slashed', '2012 burnt teak', 'already planted',
#        'Diameter taken with diameter tape', 'Tape',
#        'Hole in it. Diameter taken with diameter tape',
#        'Measured with diameter tape. Diameter taken with diameter tape',
#        'Diameter < 0. Diameter taken with diameter tape',
#        'diseasesed - Diameter taken with diameter tape',
# ...

# %%
df.shape
# Out:
# (8082608, 14)

# %%
# Check for tree species that are not needed. Only teak trees are needed.
df['Tree SPECIES'].unique()
# Out:
# array(['Teak', 'York', 'onyono', 'Mahogany', None, 'Albizia',
#        'Awiemfosamina', 'Kyenkyen', 'Sofo', 'Onyina', 'Cassia', 'Wawa',
#        'Unknown indigenous', 'Asanfena', 'Hontan', 'Akuakuo-Ninsuo',
#        'Okoro', 'Nyankyerene', 'Watapuo', 'Akonkodie', 'Mango',
#        'kwakuanisuo', 'Hyedua', 'Nyamedua', 'kotrenfro', 'Ofram',
#        'Konkroma', 'Cedrela', 'Khaya ivorensis', 'Albizia adianthifolia',
#        'Kane', 'Wama', 'Wonton', 'Odum', 'Trilepisium madagascariense',
#        'Tetrapleura tetraptera', 'Kusia', 'Okure', 'Foto', 'Womba',
#        'Alstonia boonei', 'Anacardium occidentale', 'Afzelia', 'Otie',
#        'coconisuol', 'prekese', 'Kotreamfo', 'Acacia', 'Akye', 'Nofotene',
#        'Acasia', 'Kigelia africana', 'Prekese', 'Kookonisuo'],
#       dtype=object)

# %%
# Remove all unwanted tree species except teak species
df = df[(df['Tree SPECIES'].str.lower() == 'teak')]

# %%
# Verify
df['Tree SPECIES'].unique()
# Out:
# array(['Teak'], dtype=object)

# %%
df.shape
# Out:
# (8038316, 14)

# %%
# Check for abnormal data using h/d ratio
df['hd_ratio'] = (df['height_m'] / df['dbh_cm']) * 100

df.head()
# Out:
#   plantation block  year planted  block area (ha) plot  Default plot size  \
# 0    Tain II   B39          2013        63.327094    1              729.0
# 1    Tain II   B39          2013        63.327094    1              729.0
# 2    Tain II   B39          2013        63.327094    1              729.0
# 3    Tain II   B39          2013        63.327094    1              729.0
# 4    Tain II   B39          2013        63.327094    1              729.0
#
#   Plot type area_type  monitoring year  tree_id Tree SPECIES  height_m  \
# 0    Square      Teak           2018.0     71.0         Teak      7.25
# 1    Square      Teak           2018.0     71.0         Teak      7.25
# 2    Square      Teak           2018.0     71.0         Teak      7.25
# 3    Square      Teak           2018.0     71.0         Teak      7.25
# 4    Square      Teak           2018.0     71.0         Teak      7.25
#
#    dbh_cm     remarks   hd_ratio
# 0    12.0  Fire scars  60.416667
# ...

# %%
# Remove data with h/d ratio less 30
df = df[~(df['hd_ratio'] < 30)]
df.shape
# Out:
# (8035024, 15)

# %%
# Summary statistics of the dataset 
df[['height_m', 'dbh_cm']].describe().apply(lambda s: s.apply(lambda x: f"{x:.4f}"))
# Out:
#            height_m        dbh_cm
# count  8035024.0000  8035024.0000
# mean         9.5031       11.6423
# std          4.9159        6.9378
# min          0.0000        0.0000
# 25%          5.8000        6.2242
# 50%         10.0000       11.8000
# 75%         13.2500       16.6000
# max         37.2500       52.7000

# %%
# Plot the relationship of height and diameter
df.plot(kind='scatter', x='dbh_cm', y='height_m')
# Out:
# <Axes: xlabel='dbh_cm', ylabel='height_m'>

# %%
# Distribution of height and diameter data using boxplot
df[['height_m', 'dbh_cm']].boxplot()
# Out:
# <Axes: >

# %%
# Diameter distribution
df['dbh_cm'].plot.hist(bins=30, title="DBH Distribution")
# Out:
# <Axes: title={'center': 'DBH Distribution'}, ylabel='Frequency'>

# %%
# Height Distribution
df['height_m'].plot.hist(bins=30, title="Height Distribution")
# Out:
# <Axes: title={'center': 'Height Distribution'}, ylabel='Frequency'>

# %%
df['Age'] = df['monitoring year'] - df['year planted']
df.head()
# Out:
#   plantation block  year planted  block area (ha) plot  Default plot size  \
# 0    Tain II   B39          2013        63.327094    1              729.0
# 1    Tain II   B39          2013        63.327094    1              729.0
# 2    Tain II   B39          2013        63.327094    1              729.0
# 3    Tain II   B39          2013        63.327094    1              729.0
# 4    Tain II   B39          2013        63.327094    1              729.0
#
#   Plot type area_type  monitoring year  tree_id Tree SPECIES  height_m  \
# 0    Square      Teak           2018.0     71.0         Teak      7.25
# 1    Square      Teak           2018.0     71.0         Teak      7.25
# 2    Square      Teak           2018.0     71.0         Teak      7.25
# 3    Square      Teak           2018.0     71.0         Teak      7.25
# 4    Square      Teak           2018.0     71.0         Teak      7.25
#
#    dbh_cm     remarks   hd_ratio  Age
# 0    12.0  Fire scars  60.416667  5.0
# ...

# %%
# Age vs Diameter
df.plot.scatter('Age', 'dbh_cm')
# Out:
# <Axes: xlabel='Age', ylabel='dbh_cm'>

# %%
# From the plot, it is realized that there some negative ages in the dataset
# which need to be corrected

# 1. Check data type of the monitoring year
df['monitoring year'].dtype
# Out:
# dtype('float64')

# %%
# Removed the data with negative ages from the dataset
df = df[~(df['monitoring year'] < df['year planted'])]

# %%
df.plot.scatter('Age', 'dbh_cm')
# Out:
# <Axes: xlabel='Age', ylabel='dbh_cm'>

# %%
# Age vs Height
df.plot.scatter('Age', 'height_m')
# Out:
# <Axes: xlabel='Age', ylabel='height_m'>

# %%
# Feature Engineering
df_feat = df.copy()

df_feat = df_feat.sort_values(['plot', 'monitoring year'])
df_feat.head()
# Out:
#        plantation block  year planted  block area (ha) plot  \
# 782148   Akumadan    2A          2008        77.853644    1
# 782149   Akumadan    2A          2008        77.853644    1
# 782150   Akumadan    2A          2008        77.853644    1
# 782151   Akumadan    2A          2008        77.853644    1
# 782152   Akumadan    2A          2008        77.853644    1
#
#         Default plot size Plot type area_type  monitoring year  tree_id  \
# 782148              200.0  Circular      Teak           2009.0     12.0
# 782149              200.0  Circular      Teak           2009.0     12.0
# 782150              200.0  Circular      Teak           2009.0     12.0
# 782151              200.0  Circular      Teak           2009.0     12.0
# 782152              200.0  Circular      Teak           2009.0     12.0
#
#        Tree SPECIES  height_m    dbh_cm remarks    hd_ratio  Age
# 782148         Teak      2.72  2.228169    None  122.073315  1.0
# ...

# %%
# Calculate growth rates
df_feat['dbh_growth'] = df_feat.groupby('plot')['dbh_cm'].diff()
df_feat['height_growth'] = df_feat.groupby('plot')['height_m'].diff()
df_feat['time_interval'] = df_feat.groupby('plot')['monitoring year'].diff()

# %%
# Derived features
form_factor = 0.5 # Estimated form factor

df_feat['basal_area'] = np.pi * (df_feat['dbh_cm']/200)**2
df_feat['volume'] = df_feat['basal_area'] * df_feat['height_m'] * form_factor

# %%
# Age-related features
df_feat['age_squared'] = df_feat['Age']**2
df_feat['age_cubed'] = df_feat['Age']**3
df_feat['log_age'] = np.log(df_feat['Age'] + 1)
df_feat['sqrt_age'] = np.sqrt(df_feat['Age'])

df_feat.head()
# Out:
#        plantation block  year planted  block area (ha) plot  \
# 782148   Akumadan    2A          2008        77.853644    1
# 782149   Akumadan    2A          2008        77.853644    1
# 782150   Akumadan    2A          2008        77.853644    1
# 782151   Akumadan    2A          2008        77.853644    1
# 782152   Akumadan    2A          2008        77.853644    1
#
#         Default plot size Plot type area_type  monitoring year  tree_id  ...  \
# 782148              200.0  Circular      Teak           2009.0     12.0  ...
# 782149              200.0  Circular      Teak           2009.0     12.0  ...
# 782150              200.0  Circular      Teak           2009.0     12.0  ...
# 782151              200.0  Circular      Teak           2009.0     12.0  ...
# 782152              200.0  Circular      Teak           2009.0     12.0  ...
#
#         Age  dbh_growth  height_growth time_interval  basal_area   volume  \
# ...

# %%
# Lag features for growth prediction
df_feat['prev_dbh'] = df_feat.groupby('plot')['dbh_cm'].shift(1)
df_feat['prev_height'] = df_feat.groupby('plot')['height_m'].shift(1)

df_feat.head()
# Out:
#        plantation block  year planted  block area (ha) plot  \
# 782148   Akumadan    2A          2008        77.853644    1
# 782149   Akumadan    2A          2008        77.853644    1
# 782150   Akumadan    2A          2008        77.853644    1
# 782151   Akumadan    2A          2008        77.853644    1
# 782152   Akumadan    2A          2008        77.853644    1
#
#         Default plot size Plot type area_type  monitoring year  tree_id  ...  \
# 782148              200.0  Circular      Teak           2009.0     12.0  ...
# 782149              200.0  Circular      Teak           2009.0     12.0  ...
# 782150              200.0  Circular      Teak           2009.0     12.0  ...
# 782151              200.0  Circular      Teak           2009.0     12.0  ...
# 782152              200.0  Circular      Teak           2009.0     12.0  ...
#
#        height_growth  time_interval  basal_area   volume  age_squared  \
# ...

# %%
# Handle missing values
df_feat.dropna()
# Out:
#         plantation block  year planted  block area (ha) plot  \
# 817314    Akumadan    2A          2008        77.853644    1
# 817315    Akumadan    2A          2008        77.853644    1
# 817316    Akumadan    2A          2008        77.853644    1
# 817317    Akumadan    2A          2008        77.853644    1
# 817318    Akumadan    2A          2008        77.853644    1
# ...            ...   ...           ...              ...  ...
# 8478819    Tain II   A32          2017        67.653726  991
# 8478820    Tain II   A32          2017        67.653726  991
# 8478821    Tain II   A32          2017        67.653726  991
# 8478822    Tain II   A32          2017        67.653726  991
# 8478823    Tain II   A32          2017        67.653726  991
#
#          Default plot size Plot type area_type  monitoring year  tree_id  ...  \
# 817314               200.0  Circular      Teak           2011.0      4.0  ...
# ...

# %%
df_feat = df_feat[(df_feat['dbh_cm'] > 0)]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df_feat = df_feat[(df_feat['dbh_cm'] > 0)]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4152, in DataFrame._getitem_bool_array(self, key)
#    4149 key = check_bool_indexer(self.index, key)
#    4151 if key.all():
# -> 4152     return self.copy(deep=None)
# ...

# %%
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import xgboost as xgb

# %%
# Future DBH
target = 'dbh_cm'

exclude_cols = ['plot', 'monitoring year', 'dbh_growth', 'height_growth', 'time_interval']
feature_cols = [col for col in df_feat.columns if col not in exclude_cols and col != target]

X = df_feat[feature_cols]
y = df_feat[target]

# Encode categorical variables
categorical_cols = X.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col].astype(str))
# Out:
# C:\Users\GILBERT FG\AppData\Local\Temp\ipykernel_13280\4131316781.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))
# C:\Users\GILBERT FG\AppData\Local\Temp\ipykernel_13280\4131316781.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))
# C:\Users\GILBERT FG\AppData\Local\Temp\ipykernel_13280\4131316781.py:14: SettingWithCopyWarning:
# ...

# %%
# Splitting the dataset by year. 
# Use earlier years for training and later years for testing
df_sorted = df_feat.sort_values('monitoring year') # sort the dataset according to monitoring years
split_year = df_sorted['monitoring year'].quantile(0.8) # set 80% of the dataset for training

X_train = X[df_feat['monitoring year'] <= split_year]
y_train = y[df_feat['monitoring year'] <= split_year]
X_test = X[df_feat['monitoring year'] > split_year]
y_test = y[df_feat['monitoring year'] > split_year]


print(f"Training set size: {X_train.shape}")
print(f"Test set size: {y_test.shape}")
# Out:
# Training set size: (6658576, 21)
# Test set size: (1375228,)

# %%
# Out:
#         plantation block  year planted  block area (ha) plot  \
# 0          Tain II   B39          2013        63.327094    1
# 1          Tain II   B39          2013        63.327094    1
# 2          Tain II   B39          2013        63.327094    1
# 3          Tain II   B39          2013        63.327094    1
# 4          Tain II   B39          2013        63.327094    1
# ...            ...   ...           ...              ...  ...
# 8577775   Akumadan   20A          2006        65.096183  450
# 8577776   Akumadan   20A          2006        65.096183  450
# 8577777   Akumadan   20A          2006        65.096183  450
# 8577778   Akumadan   20A          2006        65.096183  450
# 8577779   Akumadan   20A          2006        65.096183  450
#
#          Default plot size Plot type area_type  monitoring year  tree_id  \
# 0                    729.0    Square      Teak           2018.0     71.0
# 1                    729.0    Square      Teak           2018.0     71.0
# ...

# %%
# Scale numerical features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
x_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 3
#       1 # Scale numerical features
#       2 scaler = StandardScaler()
# ----> 3 X_train_scaled = scaler.fit_transform(X_train)
#       4 x_test_scaled = scaler.transform(X_test)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...
